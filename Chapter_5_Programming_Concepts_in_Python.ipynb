# %% [markdown]
# Numpy Libary: It is an open-source library that contains a great deal of mathematical functionality, such as common statistical and linear algebra techniques.
#
# Quant Technique: Random Number Generation; Linear Algebra Functions (e.g., Matrix Decompositions); Fourier Transform Calculations

# %% [markdown]
# Pandas Library: working with relational data, such as interacting
# with databases, reading or writing text files, or parsing a website to extract data, and provides a set of functions that facilitate the process of retrieving or writing data.
#
# Common Functionality: Index and slice our data; Append to our data; Merge our data with another dataset; Repeat our data; Iterate through our data with a for loop

# %% [markdown]
# Tuples: a flexible and easy to use data structure that can handle heterogeneous data with multiple underlying types. As such, tuples provide us with a convenient data structure to store unstructured data.

# %%
tuple1 = ( 'SPY' , '2018-09-06' , '290.31') #one-dimensional tuple: each have a different underlying datatype
print(tuple1)
# Out:
# ('SPY', '2018 -09 -06', '290.31')

# %%
tuple1 = ( 'SPY' , '290.31' , 1) #multi dimensional: each embedded tuple can be of different lengths and contain different types
tuple2 = (181.24 , 'QQQ')
tuples = ( tuple1 , tuple2 )
print(tuples)
# Out:
# (('SPY', '290.31', 1), (181.24, 'QQQ'))

# %% [markdown]
# Lists: Like tuples, lists can also be nested and multi-dimensional. Lists can also support data with different data types in different elements

# %%
list1 = ['SPY' , 1 , 2]
list2 = [0 , 'QQQ']
lists = [list1 , list2]
print (lists [0][1])
print(lists)
# Out:
# 1
# [['SPY', 1, 2], [0, 'QQQ']]

# %%
list1 = ['SPY' , 1 , 2]
list1 [0] = 'IWM'   #lists are mutable whereas tuples are immutable, we can modify the elements in a list
list2 = [0 , 'QQQ']
lists = [ list1 , list2 ]
print(lists)
# Out:
# [['IWM', 1, 2], [0, 'QQQ']]

# %% [markdown]
# Array: performing calculations on numeric data and built-in mathematical functionality, such as addition, multiplication and division are defined on arrays

# %%
import numpy as np
a = np.array ([1 ,2 ,3])
a [1] = 3
b = np.array ([4 ,5 ,6])
c = a + b  #c = a * b
print(a)
print(b)
print(c)
# Out:
# [1 3 3]
# [4 5 6]
# [5 8 9]

# %%
a = np.array ([1 ,2 ,3])
b = np.array ([4 ,5 ,6])
c = a.dot (b )
d = np.dot (a , b)  #matrix multiplication

print (c)
# Out:
# 32

# %% [markdown]
# The main difference between a list and a numpy array is the presence of mathematical operations such as the + operator and the * operator
#
# List: better for handling unstructured data that doesn't require typing or have any required consistency
#
# Numpy Array: tend to be the optimal data structure to use for numeric data sets

# %% [markdown]
# Covariance Matrices in Practice:
#
# Portfolio Optimization: where the correlation structure determines how much weight we want to invest in different assets.
#
# Simulation Algorithms: create a covariance matrix and simulate random numbers that are in line with that covariance matrix
#
# Risk Management: multi-variate simulation, where we would want to simulate all assets in a given portfolio using a specified covariance matrix

# %%
#Covariance provides the measure of strength of correlation between two variable or more set of variables. The covariance matrix element Cij is the covariance of xi and xj. The element Cii is the variance of xi.
#If COV(xi, xj) = 0 then variables are uncorrelated
#If COV(xi, xj) > 0 then variables positively correlated
#If COV(xi, xj) < 0 then variables negatively correlated

#Syntax: numpy.cov(m, y=None, rowvar=True, bias=False, ddof=None, fweights=None, aweights=None)

x = np.array([[0, 3, 4], [1, 2, 4], [3, 4, 5]])
print("Shape of array:\n", np.shape(x))
print("Covariance matrix of x:\n", np.cov(x))
# Out:
# Shape of array:
#  (3, 3)
# Covariance matrix of x:
#  [[4.33333333 2.83333333 2.        ]
#  [2.83333333 2.33333333 1.5       ]
#  [2.         1.5        1.        ]]

# %%
x = [1.23, 2.12, 3.34, 4.5]
y = [2.56, 2.89, 3.76, 3.95]

# find out covariance with respect  rows
cov_mat = np.stack((x, y), axis = 1)  #when axis = 0, with respect columns

print("shape of matrix x and y:", np.shape(cov_mat))
print("what's in cov_mat:", cov_mat)

print(np.cov(cov_mat))
# Out:
# shape of matrix x and y: (4, 2)
# what's in cov_mat: [[1.23 2.56]
#  [2.12 2.89]
#  [3.34 3.76]
#  [4.5  3.95]]
# [[ 0.88445  0.51205  0.2793  -0.36575]
#  [ 0.51205  0.29645  0.1617  -0.21175]
#  [ 0.2793   0.1617   0.0882  -0.1155 ]
#  [-0.36575 -0.21175 -0.1155   0.15125]]

# %%
# Correlation matrices
array1 = np.array([ 2, 4, 8])
array2 = np.array([ 3, 2, 1])

# pearson product-moment correlation
# coefficients of the arrays
rslt2 = np.corrcoef(array1, array2)
print(rslt2)
# Out:
# [[ 1.         -0.98198051]
#  [-0.98198051  1.        ]]

# %% [markdown]
# Series: A pandas series is a one dimensional array with an index. Series objects are convenient for working with time-series data, where the index would
# naturally correspond to a date

# %%
import pandas as pd
s = pd.Series (data = np.random.random(size =5),
index =['2014' , '2015' , '2016', '2017' , '2018'])
print(s)
# Out:
# 2014    0.551009
# 2015    0.659880
# 2016    0.315348
# 2017    0.791484
# 2018    0.374170
# dtype: float64

# %% [markdown]
# DataFrame: tabular data structures where both the rows and columns can be named.
#
# One of the main strengths of Data Frame objects is their built-in ability for data transformations, such as joining data frames to another data frame, or grouping or aggregating our data. This ability to use a Data Frame to transform, aggregate and merge our data, as we often do in SQL, is a significant benefit of the pandas library and coding in Python.
#
# https://pandas.pydata.org/docs/reference/frame.html

# %%
import pandas as pd
df = pd.DataFrame (data = np.random.random (size =(5 ,3)) ,
                  index =['2014', '2015', '2016', '2017', '2018'] ,
                  columns =[ 'SPY','QQQQ', 'IWM' ])
print(df)
# Out:
#            SPY      QQQQ       IWM
# 2014  0.937462  0.433152  0.983967
# 2015  0.126288  0.173529  0.618802
# 2016  0.202084  0.821180  0.519036
# 2017  0.128960  0.563107  0.128700
# 2018  0.860086  0.482467  0.302370

# %%
#Accessing Rows or Columns in DataFrames
df = pd.DataFrame({'month': [1, 4, 7, 10],
                   'year': [2011, 2012, 2013, 2014],
                   'sale': [55, 40, 84, 31]})
df.set_index ( 'year' , inplace = True )
print(df)

df_subset = df.loc [[2013, 2014]]  #label based, also be used with a boolean array
print('based on index:', df_subset)

df_subset = df.iloc[[0, 1], :] #integer position based
print('based on row number:',df_subset)

print (df.iloc[[True, False, True, False]]) #With a boolean mask the same length as the index.
# Out:
#       month  sale
# year
# 2011      1    55
# 2012      4    40
# 2013      7    84
# 2014     10    31
# based on index:       month  sale
# year
# 2013      7    84
# 2014     10    31
# based on row number:       month  sale
# year
# 2011      1    55
# 2012      4    40
#       month  sale
# year
# 2011      1    55
# 2013      7    84

# %%
#Merging DataFrames
#DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False, validate=None)[source]

one = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                      'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})
another = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                          'B': ['B0', 'B1', 'B2']})
#Join DataFrames using their indexes.
one.join(another, lsuffix='_caller', rsuffix='_other')
# Out:
#   key_caller   A key_other    B
# 0         K0  A0        K0   B0
# 1         K1  A1        K1   B1
# 2         K2  A2        K2   B2
# 3         K3  A3       NaN  NaN
# 4         K4  A4       NaN  NaN
# 5         K5  A5       NaN  NaN

# %%
#set key to be the index
one.set_index('key').join(another.set_index('key'))
one.join(another.set_index('key'), on='key')
# Out:
#   key   A    B
# 0  K0  A0   B0
# 1  K1  A1   B1
# 2  K2  A2   B2
# 3  K3  A3  NaN
# 4  K4  A4  NaN
# 5  K5  A5  NaN

# %%
#Concatenating and Appending DataFrames
#pandas.concat(objs, *, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=None)
s1 = pd.Series(['a', 'b'])
s2 = pd.Series(['c', 'd'])
pd.concat([s1, s2], ignore_index=True) #Clear the existing index and reset it in the result
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
pd.concat([s1, s2], keys=['s1', 's2'],
                    names=['Series name', 'Row ID']) #Label the index keys
# Out:
# Series name  Row ID
# s1           0         a
#              1         b
# s2           0         c
#              1         d
# dtype: object

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])
df4 = pd.DataFrame([['bird', 'polly'], ['monkey', 'george']],
                   columns=['animal', 'name'])
pd.concat([df1, df4], axis=1) #Combine DataFrame objects horizontally along the x axis by passing in axis=1.
# Out:
#   letter  number  animal    name
# 0      a       1    bird   polly
# 1      b       2  monkey  george

# %%
#Returning the first and last rows in a Data Frame
df4.head(1)
df4.tail(1) #The head and tail functions return the first n rows and last n rows
# Out:
#    animal    name
# 1  monkey  george

# %%
#Transforming DataFrames
#pandas.pivot(data, *, columns, index=_NoDefault.no_default, values=_NoDefault.no_default)
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df.pivot(index='foo', columns='bar')['baz'] #reshape tables using unique values from specified indices and columns
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %%
#Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#pandas.melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index=True)
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})
pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
pd.melt(df, id_vars=['A'], value_vars=['B', 'C'],
        var_name='myVarname', value_name='myValname')
# Out:
#    A myVarname  myValname
# 0  a         B          1
# 1  b         B          3
# 2  c         B          5
# 3  a         C          2
# 4  b         C          4
# 5  c         C          6

# %%
#Performing Calculations within a Data Frame
#Commonly used methods include mean, std, min, max, etc.
df = pd.DataFrame ( data = np.random.random(size =(5,3)) ,
                    index =['2009', '2010', '2011', '2012', '2013'] ,
                    columns =[ 'SPY', 'AAPL', 'GOOG' ])
print ( df.mean () )
print ( df.std () )
print ( df.min () )
print ( df.rolling (3).mean () )
# Out:
# SPY     0.514198
# AAPL    0.583026
# GOOG    0.461162
# dtype: float64
# SPY     0.295423
# AAPL    0.341448
# GOOG    0.269613
# dtype: float64
# SPY     0.177298
# AAPL    0.241265
# GOOG    0.232018
# dtype: float64
#            SPY      AAPL      GOOG
# 2009       NaN       NaN       NaN
# 2010       NaN       NaN       NaN
# 2011  0.385324  0.557216  0.482031
# 2012  0.326523  0.699126  0.406126
# 2013  0.579477  0.705239  0.382767

# %%
#Applying User-defined Functions to DataFrames

#Dataframe.assign() on a Single Column / Multiple Columns
#Dataframe.apply() on a Single Row / Multiple Rows
#Lambda Function on Multiple Rows and Columns Simultaneously

values= [['Rohan',455],['Elvish',250],['Deepak',495],
         ['Soni',400],['Radhika',350],['Vansh',450]]

df = pd.DataFrame(values,columns=['Name','Total_Marks'])

df.assign(Percentage = lambda x: (x['Total_Marks'] /500 * 100))
# Out:
#       Name  Total_Marks  Percentage
# 0    Rohan          455        91.0
# 1   Elvish          250        50.0
# 2   Deepak          495        99.0
# 3     Soni          400        80.0
# 4  Radhika          350        70.0
# 5    Vansh          450        90.0

# %%
values_list = [[15, 2.5, 100], [20, 4.5, 50], [25, 5.2, 80],
               [45, 5.8, 48], [40, 6.3, 70], [41, 6.4, 90],
               [51, 2.3, 111]]
df = pd.DataFrame(values_list, columns=['Field_1', 'Field_2', 'Field_3'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])

# Apply function numpy.square() to square
df.apply(lambda x: np.square(x) if x.name == 'd' else x, axis=1)
# Out:
#    Field_1  Field_2  Field_3
# a     15.0     2.50    100.0
# b     20.0     4.50     50.0
# c     25.0     5.20     80.0
# d   2025.0    33.64   2304.0
# e     40.0     6.30     70.0
# f     41.0     6.40     90.0
# g     51.0     2.30    111.0

# %% [markdown]
# Dictionary: consists of a series of key-value pairs
#
# The key in a dictionary must be unique, and the keys are also immutable, meaning they cannot be changed once they are created. Values in a dictionary can be modified or added for a specific key using the [] operator.
#
# This function is structured such that the key-value pair will be updated if the key exists, otherwise a new key-value pair will be added to the dictionary

# %%
thisdict = {}
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}

thisdict["color"] = "white"  #Add a new item to the original dictionary

for x, y in thisdict.items():
  print(x, y)

# %% [markdown]
# Random Number Generation: a core part of building a simulation algorithm, and is also central to statistical bootstrapping and other applications.

# %%
# Uniform Distribution: all values have equal probability

#create a matrix of uniformly distributed random numbers between 0 and 1
rnds = np.random.rand (100,100)
rnds
# Out:
# array([[0.29662035, 0.82204545, 0.54956157, ..., 0.89793329, 0.45776119,
#         0.13829167],
#        [0.90258702, 0.97809997, 0.01377644, ..., 0.5131364 , 0.05177651,
#         0.85187271],
#        [0.12321643, 0.46350219, 0.35386364, ..., 0.88076616, 0.57999321,
#         0.89981762],
#        ...,
#        [0.36839408, 0.58867759, 0.51841482, ..., 0.27911127, 0.2535312 ,
#         0.381816  ],
#        [0.66935932, 0.54186606, 0.29024716, ..., 0.28422213, 0.64403831,
#         0.39540715],
#        [0.23934059, 0.65870668, 0.32400507, ..., 0.37386899, 0.69269932,
#         0.35728083]])

# %%
# Normal Distribution

mat_shape = (100 , 100)
norm_rnds = np.random.normal (0.0 , 1.0 , mat_shape )
norm_rnds
# Out:
# array([[ 1.55522046, -3.5933985 ,  0.49289731, ..., -0.09880901,
#          0.75721102, -0.24073753],
#        [ 0.17445724,  0.07555759, -0.14962441, ...,  0.77239501,
#         -1.31784621, -0.55298415],
#        [ 0.24852793, -0.40964684, -1.09121066, ...,  0.50093412,
#         -1.3880144 , -0.71679954],
#        ...,
#        [-0.57018712, -0.13888801,  1.08829899, ...,  1.07409206,
#          1.2716664 , -0.67240071],
#        [ 0.33310999,  1.48630629, -0.50068886, ...,  0.22702272,
#          0.18382579, -1.52167463],
#        [-0.71996007,  0.73725717, -1.19318236, ..., -0.36936572,
#          1.03215806, -0.52853858]])

# %%
# multi-variate normal distribution
# random.multivariate_normal(mean, cov, size=None, check_valid='warn', tol=1e-8)

#Spherical covariance (cov is a multiple of the identity matrix)
#Diagonal covariance (cov has non-negative elements, and only on the diagonal)

mean = [0, 0]
cov = [[1, 0], [0, 100]]  # diagonal covariance, Covariance indicates the level to which two variables vary together

import matplotlib.pyplot as plt
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

# %%
# Exponential Distribution
# The exponential distribution is a continuous analogue of the geometric distribution.
# It describes many common situations, such as the size of raindrops measured over many rainstorms, or the time between page requests to Wikipedia

n = 10000
time_between_calls = np.random.default_rng().exponential(scale=4, size=n) #A real world example: Assume a company has 10000 customer support agents and the average time between customer calls is 4 minutes.

# What is the probability that a customer will call in the next 4 to 5 minutes?
x = ((time_between_calls < 5).sum())/n
y = ((time_between_calls < 4).sum())/n
x-y
# Out:
# 0.08289999999999997

# %% [markdown]
# Linear Regression
#
# Commonly used in The Fama-French Three-Factor Model (an expansion of the Capital Asset Pricing Model (CAPM))

# %%
import numpy as np
from sklearn import datasets , linear_model

Xs = np.random.rand (100 , 2)
Ys = np.random.rand (100 , 1)

#Create linear regression object
regr = linear_model.LinearRegression ()

#Train the model using the training sets
regr.fit (Xs , Ys)
print (regr.coef_ )
# Out:
# [[ 0.04828056 -0.15430698]]

# %% [markdown]
# Autocorrelation Tests
#
# we distinguished between stationary and non-stationary time series, and showed how we can use an augmented Dickey-Fuller test to check statistically whether a time series is stationary or non-stationary, using statsmodels.tsa.stattools.adfuller
# the null hypothesis that the data is non-stationary, meaning that higher t-stat sand lower p-values indicate higher confidence that the data is stationary.
#
# Autoregressive Moving-Average (ARMA) Models:  a combination of two commonly used time series processes, the autoregressive (AR) process and the moving-average (MA) process, using the statsmodels.tsa.arima.model.ARIMA
#
# Commonly used to measure the relationship between current returns from an asset and its previous returns / tests of market efficiency, with statistically significant mean-reversion or momentum coefficients violating the so-called weak-form of market efficiency.
#
#
# Stationarity tests and ARMA models are commonly used in forecasting and alpha research. If we are able to find tradeable market quantities that exhibit mean reversion or momentum, then the potential reward is high.

# %%
# Matrix Decompositions
#  calculate these decompositions for an arbitrary matrix

# cholesky decomposition: it requires an input matrix that is positive definite
#linalg.cholesky(a, /, *, upper=False)[source]
mat = np.random.rand (5 , 5) # full - rank square matrix
A = mat @ mat.T # matrix product to get positive definite matrix
L = np.linalg.cholesky(A) # lower triangular matrix
L
# Out:
# array([[ 1.08803032,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.83282107,  0.84312574,  0.        ,  0.        ,  0.        ],
#        [ 0.56124702,  1.03353167,  0.35742726,  0.        ,  0.        ],
#        [ 0.38555062,  0.68386052,  0.07746036,  0.49755682,  0.        ],
#        [ 0.82901387,  0.76598584,  0.16419221, -0.03720173,  0.29775428]])

# %%
# eigenvalue decomposition
# as long as the input matrix is positive semi-definite

from numpy import linalg as LA
eigenvalues, eigenvectors = LA.eig(np.diag((1, 2, 3)))
eigenvalues # array([1., 2., 3.])
eigenvectors #array([[1., 0., 0.],
             #       [0., 1., 0.],
             #       [0., 0., 1.]])

mat = np.vstack ([ np.random.rand (4 , 5) , np.zeros (5)]) # rank - deficient square matrix
A = mat @ mat . T # matrix product to get positive - semidefinite matrix
w , v = LA.eig ( A) # eigenvalues w and normalized eigenvectors v
w
v
# Out:
# array([[ 0.6138847 ,  0.22501964,  0.70031587, -0.28647761,  0.        ],
#        [ 0.31235103,  0.77811503, -0.35451528,  0.41387528,  0.        ],
#        [ 0.21086013,  0.09555562, -0.54514471, -0.80574461,  0.        ],
#        [ 0.69362844, -0.57859509, -0.29443818,  0.31211129,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  1.        ]])

# %% [markdown]
# Object-Oriented Programming
# Object-oriented programming is based on a set of underlying principles that are meant to help us understand why code that is based on classes or objects is more scalable and robust than code based on functions
#
# There are four main tenets of object-oriented programming:
# • Inheritance: allows us to create class hierarchies and have classes inherit functionality from other classes.
# • Encapsulation: an object's internal representation is hidden from outside the
# object.
# • Abstraction: exposing necessary functionality from an object while
# abstracting other details from the user of a class.
# • Polymorphism: ability of a sub-class to take on different forms and either
# have their own behavior or inherit their behavior from a parent

# %% [markdown]
# Classes: define complex user-defined data types. These data types can contain within them a variety of embedded functionality and components. (often contain certain properties or attributes which help us define the structure of our data type)
#
# Classes can also define functions, or methods, that act on themselves or other classes.
#
# Classes must have at least one constructor, which is called when the class is initialized and may also contain any arbitrary number of attributes and class methods.

# %%
class Position:
  def __init__(self):
    self.shares = 0
    self.prices = 0
    print ( " initializing position " )
#All classes have a function called __init__(), which is always executed when the class is being initiated.
#Use the __init__() function to assign values to object properties, or other operations that are necessary to do when the object is being created

# %% [markdown]
# Certain classes that tend to be at the heart of many quant finance applications:
#
# • A stochastic process class that enables us to model the behavior of asset prices while switching between different SDEs.
# • An option payoff class that enables us to switch between various vanilla and
# exotic option payoff structures.
# • An instrument class that defines the various attributes of an instrument, such
# as a stock, bond or option
# • A back-test class that enables us to take a series of signals and historical return data and generate a set of standardized summary metrics.

# %% [markdown]
# Constructors: A constructor is a piece of code that runs when an object is initialized. Constructors are often used to assign values to the member data, or attributes, in a given class, and may also contain additional logic.
#
# Defining a constructor in Python is accomplished by creating a function with a
# certain name, __init__ and a conforming signature. A constructor must take at least
# one parameter, self, which corresponds to the current instance of the object being created. An arbitrary number of additional parameters can be passed to the constructor
# as well.

# %%
class Position:
  def __init__(self, shrs=0, px=0):
    self.shares = shrs
    self.prices = px

pos = Position()
pos2 = Position(100, 100)
print (pos2.shares)
# Out:
# 100

# %% [markdown]
# Destructors: be able to define code that executes every time an object gets destroyed. We can use destructors to make sure that file or database connections
# are released when an object is destroyed. in Python this process is handled via automatic garbage collection making destructors less commonly overridden and less important.
#
# Destructors in Python are specified using the name del and must also take a single parameter self. Remember that this self-parameter refers to the current instance of the class being destroyed.

# %%
class Position:
  def __init__(self, shrs=0, px=0):
    self.shares = shrs
    self.prices = px
  def __del__(self):
    print ( " deleting position " ) # here we're only using the destructor to no￾tify us that the object has been destroyed
# Destructors are called when objects are deleted. This might happen automatically, when an object goes out-of-scope, or might happen if an object is deleted explicitly using the del command.

# %% [markdown]
# Class Attributes: A key feature of object-oriented design is the ability to build classes that store their own data. This data for a class is referred to as a set of attributes, or member data, and is essentially a set of variables that are stored within, and are specific to, an instance of a class.
#
# For example: string, numeric data types, other classess like Data Frame, the Position object defined, may also be the classes that rely on an inheritance framework

# %%
class Position:
  def __init__(self, shrs=0, px=0): #create a Position class with two attributes, shares and price
    self.shares = shrs
    self.prices = px

pos = Position(100, 100)
s = pos.shares
pos.shares = 200 #these attributes are accessible to for us to read and write

# %% [markdown]
# Class Methods: functions that operate on a particular class instance
# Class methods are defined in Python similarly to defining an isolated function.
# The key differences are that class methods are defined within a given class and that the first argument is the self-parameter.
# Aside from the self-parameter, the coder can pass an arbitrary number of parameters, with arbitrary type and structure, to a class methods. Because class methods operate on an instance of a class, they can access and modify class attributes and call other class methods.

# %%
class Position:
  def __init__(self, shrs=0, px=0):
    self.shares = shrs
    self.prices = px
  def mktValue(self):
    return self.shares * self.prices

pos = Position (100, 100)
mktVal = pos.mktValue()
mktVal
# Out:
# 10000

# %% [markdown]
# Class Methods vs. Global Functions

# %%
class Position:
  def __init__(self, shrs=0, px=0):
    self.shares = shrs
    self.prices = px
  def mktValue(self):
    return self.shares * self.prices # via a Class Method, it is consistent with the object-oriented principles of abstraction and encapsulation

  def mktValue3(pos):
    return pos.shares * pos.prices #via a Global Function defined inside the Position class

def mktValue2(pos):
  return pos.shares * pos.prices # via a Global Function defined outside the Position class

  pos = Position(100, 100)
  mktVal = pos.mktValue()
  mktVal2 = mktValue2(pos)
  mktVal3 = Position.mktValue3(pos)

# %% [markdown]
# Operator Overloading: changing the definition of one of these built-in functions.
# Examples of such operators are the assignment operator, the equality operator, and the addition and multiplication operators. Full list can be found: https://www.w3schools.com/python/python_operators.asp

# %%
class Position:
  def __init__(self, shrs=0, px=0):
    self.shares = shrs
    self.prices = px
  def __add__(self, other):
    return Position(self.shares + other.shares, self.prices) # when overriding the addition operator, we simply need to define a function called add that takes two parameters, self and other
                                                             # Here 'self' refers to the current instance of the class and 'other' refers to another instance of the same class that we are adding to the current instance
pos = Position(100, 50)
pos2 = Position(100,50)
pos3 = pos + pos2
print(pos3.shares, pos3.prices) # returns a new instance of the Position class, rather than modifying the current instance.

print(pos == pos2) # the default implementation of the == operator for complex types checks whether the two objects refer to the same instance and memory location.
                   # By default, the == does not validate whether the two instances of an object have the same attribute values.

class Position:
  def __init__(self, shrs=0, px=0):
    self.shares = shrs
    self.prices = px
  def __eq__(self, other):
    return (self.shares == other.shares and self.prices == other.prices)

pos = Position(100, 50)
pos2 = Position(100,50)
print(pos == pos2)
# Out:
# 200 50
# False
# True

# %% [markdown]
# Inheritance: it enables us to create objects that exist within a class hierarchy by allowing us to create classes that are modified or specialized versions of each other.
#
# • Base Class: A higher level, more generic class with some desired basic functionality that is useful in derived classes.
#
# • Derived Class: A lower level, child class that defines a class with more specialization and inherits the functionality in the base class

# %%
class BasePosition:
  def __init__(self):
    print("initializing from BasePosition")

  def price(self):
    print("calling base class price function")

class DerivedPosition(BasePosition):
  def __init__(self):
    super().__init__() #the derived class explicitly calls the BasePosition class constructor by invoking the super() function
                       #This ability to inherit functionality from derived classes, while overriding or adding new functionality where necessary, is a critical part benefit of using object-oriented programming, and of writing scalable, re-usable, robust code.

    print("initializing from DerivedPosition")

  def price(self):
    print("calling derived class price function")

b = BasePosition()
d = DerivedPosition()
# Out:
# initializing from BasePosition
# initializing from BasePosition
# initializing from DerivedPosition

# %% [markdown]
# Polymorphism: One of the key drivers behind our ability to write generic code via inheritance is the concept of polymorphism.

# %%
pip install QuantLib-Python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 41.2 MB/s eta 0:00:00
# ...

# %%
class StochasticProcess:
    def __init__(self, parameter):
        self.parameter = parameter

    def price(self):
        return f"Base Stochastic Process with parameter {self.parameter}"

class BlackScholesProcess(StochasticProcess):
    def __init__(self, parameter):
        super().__init__(parameter)

    def price(self):
        return f"Black-Scholes Process with parameter {self.parameter}"

bsProcess = BlackScholesProcess(0.1)
baseProcess = StochasticProcess(0.1)

my_procs = [bsProcess, baseProcess] #two different types of stochastic pro￾cesses are stored within the same list and that the price function corresponding to the appropriate place in the class hierarchy is called inside the loop.
for stoch_proc in my_procs:
  print(stoch_proc.price())
# Out:
# Black-Scholes Process with parameter 0.1
# Base Stochastic Process with parameter 0.1

# %%
import QuantLib as ql
#Sample code for The Black-Scholes process from ChatGPT
# Set up the market data
spot_price = 100.0  # current stock price
strike_price = 100.0  # option strike price
risk_free_rate = 0.05  # risk-free interest rate
volatility = 0.20  # volatility of the underlying stock
maturity_date = ql.Date(15, 6, 2024)  # option maturity date
calculation_date = ql.Date(15, 6, 2023)  # today's date

# Set the evaluation date
ql.Settings.instance().evaluationDate = calculation_date

# Create the option payoff
payoff = ql.PlainVanillaPayoff(ql.Option.Call, strike_price)

# Create the European exercise
exercise = ql.EuropeanExercise(maturity_date)

# Create the Black-Scholes process
spot_handle = ql.QuoteHandle(ql.SimpleQuote(spot_price))
rate_handle = ql.YieldTermStructureHandle(ql.FlatForward(calculation_date, risk_free_rate, ql.Actual365Fixed()))
vol_handle = ql.BlackVolTermStructureHandle(ql.BlackConstantVol(calculation_date, ql.NullCalendar(), volatility, ql.Actual365Fixed()))
bsm_process = ql.BlackScholesProcess(spot_handle, rate_handle, vol_handle)

# Create the European option
european_option = ql.EuropeanOption(payoff, exercise)

# Set up the pricing engine
european_option.setPricingEngine(ql.AnalyticEuropeanEngine(bsm_process))

# Calculate the option's NPV (Net Present Value)
option_price = european_option.NPV()

print(f"The European Call option price is: {option_price}")

# %% [markdown]
# Design Patterns: a specified set of coding structures or guidelines that lead to
# re-usable, generic code. This set of design patterns is intended to make creating objects, structuring them and communication between them more seamless
#
# Types: • Creational: deals with optimal creation/initialization of objects.
# • Structural: deals with organizing classes to form larger objects that provide
# new functionality.
# • Behavioral: deals with communications between two or more objects.
#
# Abstract Base Classes: classes within an inheritance hierarchy that aren't meant to be created themselves, but instead are meant to provide a shell with pre-determined functionality for derived classes to implement. The benefit of an abstract class is that it provides a contract that all derived classes must adhere to if they want to inherit their functionality.
#
# Factory Pattern: helping to create a class within a class hierarchy with many derived classes. It is a creational design pattern where we enable the user
# to specify the type of class within a hierarchy that they would like to create, along with some required additional arguments to create the object. Consists of a single global function that initializes and returns an instance of the appropriate base or derived class type based on a given input parameter.
#
# Singleton Pattern: Also a creational pattern, ensures that only one instance of a class can be created each time the application is run. This paradigm is useful for things that we want to make sure are unique, such as connections to databases and log files. the Singleton Pattern is implemented by making a class's constructor private and defining a static getInstance method that checks whether the class is initialized and creates it only if it has not been initialized. An example of the singleton pattern in Python is presented in the supplementary coding materials.
#
# Template Method: when we define a sketch of an algorithm in an abstract base class without defining certain details of the functionality. One example of the template method would be to define a base simulation class as an abstract base class, with a function called nextStep that is not implemented, and then define a set of derived classes that implement this method based on the specific SDE that they rely on (e.g. a Black-Scholes simulation class and a Bachelier simulation class). A corresponding coding example for the template method is
# presented in the text's supplementary materials.

# %% [markdown]
# Search Algorithms - Binary Search Algorithm: a way of searching for a value in an already sorted array. Binary search works by splitting the sorted array in half at each step, and checking whether the item in the middle is above or below the search value. The algorithm then continues by setting the left or right end point equal to the middle, depending on the result of the comparison, and then repeating the process.
#
# Binary search algorithms can be written generically such that they can apply to
# any class or data type that has certain operators defined. Binary search algorithms are also of interest to quant finance because they are based on the same underlying approach as the root finding technique bisection.

# %% [markdown]
# Sort Algorithms:
#
# Selection Sort - a naive sort algorithm that sorts by repeatedly finding the smallest value in the array and placing it at the beginning of the array.
#
# Insertion Sort - iterating sequentially through the array elements and placing the chosen element in the appropriate place in the already sorted portion of the array. The most naive implementation of this would be to simply iterate through the smaller array as well until we find the right location of the chosen element. This approach would require a nested for loop, or a while loop within a for loop.
#
# Bubble Sort - a simple sorting algorithm that works by repeatedly swapping elements that are sorted incorrectly until all elements are sorted in the correct order.
#
# Merge Sort - dividing the array in half, and merging the two halves after they have been sorted. This process is called recursively, that is, we break the array into smaller and smaller pieces until we are able to sort them. Once we have broken them into pieces that we are able to sort easily, we then aggregate the already sorted pieces by merging them sequentially. A merge sort algorithm consists of two functions, a merge function that defines how to merge two sorted halves (and preserve the sort order) and an outer function that is called recursively.
